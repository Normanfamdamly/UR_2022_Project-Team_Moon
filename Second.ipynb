# %%
import pandas as pd
import numpy as np

# %%
# Read mhcld-puf-2020-csv.csv and create DataFrame 
mental_health_data = "Resources/mhcld-puf-2020-csv.csv"
mh_df = pd.read_csv(mental_health_data)
mh_df.head()
# Out:
#    YEAR  AGE  EDUC  ETHNIC  RACE  GENDER  SPHSERVICE  CMPSERVICE  OPISERVICE  \
# 0  2020   14    -9       4     3       1           1           1           1
# 1  2020    1     2       4     1       1           2           1           2
# 2  2020    6    -9       4     4       2           2           1           1
# 3  2020   14    -9       4     3       2           1           1           2
# 4  2020   13    -9       4     3       2           1           1           1
#
#    RTCSERVICE  ...  ODDFLG  PDDFLG  PERSONFLG  SCHIZOFLG  ALCSUBFLG  \
# 0           2  ...       0       0          0          1          0
# 1           2  ...       0       0          0          0          0
# 2           2  ...       0       0          0          0          0
# 3           2  ...       0       0          0          1          0
# 4           2  ...       0       0          1          1          0
#
#    OTHERDISFLG  STATEFIP  DIVISION  REGION       CASEID
# ...

# %%
# List of all the columns
mh_df.columns
# Out:
# Index(['YEAR', 'AGE', 'EDUC', 'ETHNIC', 'RACE', 'GENDER', 'SPHSERVICE',
#        'CMPSERVICE', 'OPISERVICE', 'RTCSERVICE', 'IJSSERVICE', 'MH1', 'MH2',
#        'MH3', 'SUB', 'MARSTAT', 'SMISED', 'SAP', 'EMPLOY', 'DETNLF', 'VETERAN',
#        'LIVARAG', 'NUMMHS', 'TRAUSTREFLG', 'ANXIETYFLG', 'ADHDFLG',
#        'CONDUCTFLG', 'DELIRDEMFLG', 'BIPOLARFLG', 'DEPRESSFLG', 'ODDFLG',
#        'PDDFLG', 'PERSONFLG', 'SCHIZOFLG', 'ALCSUBFLG', 'OTHERDISFLG',
#        'STATEFIP', 'DIVISION', 'REGION', 'CASEID'],
#       dtype='object')

# %%
# Clean up the data
clean_mh_df = mh_df.drop(columns=['EDUC', 'RACE', 'SPHSERVICE',
       'CMPSERVICE', 'OPISERVICE', 'RTCSERVICE', 'IJSSERVICE', 'MH1', 'MH2',
       'MH3', 'SUB', 'MARSTAT', 'SMISED', 'SAP', 'EMPLOY', 'DETNLF', 'VETERAN',
       'LIVARAG', 'NUMMHS', 'TRAUSTREFLG', 'ANXIETYFLG', 'ADHDFLG',
       'CONDUCTFLG', 'DELIRDEMFLG', 'BIPOLARFLG', 'DEPRESSFLG', 'ODDFLG',
       'PDDFLG', 'PERSONFLG', 'SCHIZOFLG', 'ALCSUBFLG', 'OTHERDISFLG'])

# %%
clean_mh_df['AGE']=clean_mh_df['AGE'].map(str)

# %%
# Replace the age from the dataframe to match the actual data from the code book
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['1'], '5')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['2'], '13')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['3'], '16')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['4'], '19')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['5'], '22')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['6'], '27')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['7'], '32')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['8'], '37')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['9'], '42')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['10'], '47')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['11'], '52')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['12'], '57')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['13'], '62')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['14'], '65')
clean_mh_df['AGE']=clean_mh_df['AGE'].replace(['-9'], 'NaN')
clean_mh_df.head()
# Out:
#    YEAR AGE  ETHNIC  GENDER  STATEFIP  DIVISION  REGION       CASEID
# 0  2020  65       4       1         1         6       3  20200000001
# 1  2020  22       4       1         1         6       3  20200000002
# 2  2020  27       4       2         1         6       3  20200000003
# 3  2020  65       4       2         1         6       3  20200000004
# 4  2020  62       4       2         1         6       3  20200000005

# %%
clean_mh_df = clean_mh_df.dropna()
clean_mh_df = clean_mh_df.replace(-9, np.NaN).dropna(
clean_mh_df['AGE']=clean_mh_df['AGE'].map(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8252\1575362914.py in <module>
#       1 clean_mh_df = clean_mh_df.dropna()
# ----> 2 clean_mh_df['AGE']=clean_mh_df['AGE'].map(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    4235         dtype: object
#    4236         """
# -> 4237         new_values = self._map_values(arg, na_action=na_action)
#    4238         return self._constructor(new_values, index=self.index).__finalize__(
#    4239             self, method="map"
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     878
#     879         # mapper is a function
# --> 880         new_values = map_f(values, mapper)
#     881
#     882         return new_values
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
# Save clean Dataframe
clean_mh_df.to_csv('Resources/Clean_data.csv')
